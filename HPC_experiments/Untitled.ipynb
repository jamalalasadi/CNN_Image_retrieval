# %%
import sys
import os
import time
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd
import matplotlib
import matplotlib as mpl
from matplotlib import cm
blues   = cm.get_cmap(plt.get_cmap('Blues'))
greens  = cm.get_cmap(plt.get_cmap('Greens'))
reds    = cm.get_cmap(plt.get_cmap('Reds'))
oranges = cm.get_cmap(plt.get_cmap('Oranges'))
purples = cm.get_cmap(plt.get_cmap('Purples'))
greys   = cm.get_cmap(plt.get_cmap('Greys'))

# %%
# !python --version
# Out:
# Python 2.7.15 :: Anaconda, Inc.

# %%
images = pd.read_csv('/home/jamal/local.csv')
fig = plt.figure(figsize=(17, 9))
ax = fig.add_subplot(111) # Create matplotlib axes
ax2 = ax.twinx() # Create another axes that shares the same x-axis as ax.
font = {'family' : 'normal','size'   : 35}
matplotlib.rc('font', **font)
cnn_time = images['cnn_time']
accuracy = images['accuracy']
ax2.set_ylabel('CNN Prediction Accuracy (%)',fontsize=30)
ax.set_ylabel('CNN Prediction Speed (sec) ',fontsize=30)
ax.set_xlabel('Image',fontsize=30)
degrees = 70
plt.xticks(rotation=degrees)
cnn_time.plot(kind='bar', color=greens(150), ax=ax,width = 0.17, position=0,legend = False)
accuracy.plot(kind='bar', color=reds(150), ax=ax2,width = 0.17, position=1,legend = False)
ax.bar(images['cnn_time'],images['img_name'])
_ = ax.legend(["CNN Time"],loc='upper center', bbox_to_anchor=(0.35, -0.5),ncol=3,fontsize= 30)
_ = ax2.legend(["CNN Accuracy"],loc='upper center', bbox_to_anchor=(0.67, -0.5),ncol=3,fontsize= 30)
labels = [item.get_text() for item in ax.get_xticklabels()]
labels[0] = '78/03657'
labels[1] = '104/12253'
labels[2] = '147/10878'
labels[3] = '185/06373'

ax.set_xticklabels(labels, rotation=45)
ax.set(xlabel='Image Size(KB) / Image Name')

_ = ax.grid(which='both')
fig.savefig('local-experiment.pdf',dpi=800,bbox_inches='tight')

# %%
labels
# Out:
# [u'0', u'1', u'2', u'3']

# %%
images = pd.read_csv('/home/jamal/Hpc.csv')
fig = plt.figure(figsize=(17,9))
ax = fig.add_subplot(111) # Create matplotlib axes
ax2 = ax.twinx() # Create another axes that shares the same x-axis as ax.
font = {'family' : 'normal','size'   : 30}
matplotlib.rc('font', **font)
cnn_time = images['cnn_time']
accuracy = images['accuracy']
ax2.set_ylabel('CNN Prediction Accuracy (%)',fontsize=30)
ax.set_ylabel('CNN Prediction Speed (sec) ',fontsize=30)
ax.set_xlabel('Image',fontsize=30)
degrees = 70
plt.xticks(rotation=degrees)
cnn_time.plot(kind='bar', color=greens(150), ax=ax,width = 0.17, position=0,legend = False)
accuracy.plot(kind='bar', color=reds(150), ax=ax2,width = 0.17, position=1,legend = False)
ax.bar(images['cnn_time'],images['img_name'])
_ = ax.legend(["CNN Time"],loc='upper center', bbox_to_anchor=(0.35, -0.5),ncol=3,fontsize= 30)
_ = ax2.legend(["CNN Accuracy"],loc='upper center', bbox_to_anchor=(0.67, -0.5),ncol=3,fontsize= 30)
labels = [item.get_text() for item in ax.get_xticklabels()]
labels[0] = '78/03657'
labels[1] = '104/12253'
labels[2] = '147/10878'
labels[3] = '185/06373'
ax.set(xlabel='Image Size(KB) / Image Name')
ax.set_xticklabels(labels, rotation=45)
_ = ax.grid(which='both')
fig.savefig('Hpc-experiment.pdf',dpi=800,bbox_inches='tight')
